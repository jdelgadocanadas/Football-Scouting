# %%
# Importo las librerias 'pandas' y 'numpy'

import pandas as pd                      # pandas: librería para el análisis de datos
import numpy as np                       # numpy: librería especializada en el cálculo numérico y análisis de datos

# Importo las librerías y paquetes necesarios para llevar a cabo el clustering

import matplotlib.pyplot as plt          # matplotlib: Libreria para realizar gráficos
from sklearn.cluster import KMeans       # Importo la función 'Kmeans' del módulo 'cluster ' del paquete sklearn

# También voy a necesitar 'pandas' y 'numpy' pero ya fueron importadas al inicio del notebook

# %%
# Para realizar los radar charts de las jugadoras con caracteristicas similares a la que buscamos, necesitermos le paquete 'pygal'

import pygal

# %%
pip install pygal
# Out:
# Requirement already satisfied: pygal in c:\users\juan\anaconda3\lib\site-packages (2.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Adquisición de los datos

# %%
# Cargo los archivos de los partidos mediante la instrucción '.read_csv' de Pandas
# Almaceno cada uno de los archivos en una variable

tabla = pd.read_excel ('Bundesliga_Stats_90.xlsx')
tabla
# Out:
#                      Name     Goals   Assists   Chances  Chances successful  \
# 0         Nina Bruggemann  0.076923  0.000000  0.230769            0.076923
# 1            Sofie Zdebel  0.000000  0.000000  0.000000            0.000000
# 2          Sylwia Matysik  0.000000  0.000000  0.179462            0.000000
# 3           Chiara Bucher  0.638298  0.000000  0.638298            0.638298
# 4           Verena Wieder  0.253521  0.253521  0.507042            0.253521
# 5           Gianna Rackow  0.196078  0.588235  0.392157            0.196078
# 6           Gianna Rackow  0.196078  0.588235  0.392157            0.196078
# 7        Viktoria Pinther  0.000000  0.000000  0.571429            0.000000
# 8      Ann-Kathrin Vinken  0.000000  0.000000  0.000000            0.000000
# 9             Dora Zeller  0.156522  0.104348  1.304348            0.260870
# 10          Lilla Turanyi  0.000000  0.044510  0.133531            0.000000
# 11           Jessica Wich  0.151515  0.000000  0.303030            0.151515
# 12        Frederike Kempe  0.000000  0.000000  0.000000            0.000000
# 13          Kristin Kogel  0.000000  0.263158  0.394737            0.000000
# 14      Melissa Friedrich  0.183673  0.000000  0.183673            0.183673
# 15    Sandra Maria Jessen  0.000000  0.000000  0.000000            0.000000
# 16     Lara Katinka Marti  0.000000  0.100223  0.100223            0.000000
# 17       Henrike Sahlmann  0.000000  0.000000  0.000000            0.000000
# 18          Barbara Reger  0.000000  0.000000  0.000000            0.000000
# 19         Milena Nikolic  0.684611  0.052662  1.158572            0.684611
# 20      Henrietta Csiszar  0.211433  0.563821  0.422866            0.211433
# 21     Isabel Kerschowski  0.048993  0.048993  0.048993            0.048993
# 22            P. Machtens  0.000000  0.000000  0.000000            0.000000
# 23          Juliane Wirtz  0.067976  0.067976  0.135952            0.067976
# 24            Mina Tanaka  0.439024  0.109756  1.207317            0.439024
# 25          Ivana Rudelic  0.000000  0.129496  1.035971            0.000000
# 26         Kristin Demann  0.443350  0.000000  0.443350            0.443350
# 27     K. Vilhjálmsdóttir  0.000000  0.000000  0.000000            0.000000
# 28      Lina Maria Magull  0.231959  0.425258  0.889175            0.309278
# 29        Laura Donhauser  0.000000  0.000000  0.000000            0.000000
# ..                    ...       ...       ...       ...                 ...
# 9                          20                   23                 46
# 10                          0                    0                 62
# 11                         50                    0                 52
# 12                          0                    0                 74
# 13                          0                   27                 50
# 14                        100                  100                 65
# 15                          0                   29                 55
# 16                          0                   15                 50
# 17                          0                   57                 52
# 18                          0                    0                100
# 19                         59                   50                 42
# 20                         50                   39                 48
# 21                        100                   47                 62
# 22                          0                    0                 45
# 23                         50                   33                 46
# 24                         36                    0                 31
# 25                          0                   17                 39
# 26                        100                    0                 40
# 27                          0                   50                 42
# 28                         35                   50                 53
# 29                          0                    0                 33
# ..                        ...                  ...                ...
# 242                         0                    0                  0
# 243                       100                   22                 53
# 244                         0                   27                 39
# 245                         0                    0                  0
# 246                        50                  100                 65
# 247                        33                   33                 40
# 248                        67                   47                 64
# 249                        50                   30                 63
# 250                        54                   15                 46
# 251                        33                   40                 45
# 252                        14                   22                 47
# 253                        44                   33                 54
# 254                         0                   33                 60
# 255                        14                   29                 49
# 256                        40                    0                 31
# 257                         0                    0                 33
# 258                        42                   36                 57
# 259                         0                    0                 52
# 260                        18                   25                 39
# 261                         0                   35                 42
# 262                         0                    0                 50
# 263                       100                   50                 69
# 264                        33                   36                 27
# 265                        24                   25                 67
# 266                        44                   37                 37
# 267                        31                   34                 53
# 268                        35                   20                 62
# 269                        20                   31                 56
# 270                         0                   36                 57
# 271                        50                   29                 51
#
#      Challenges in defence won, %  Challenges in attack won, %  \
# 0                              62                           69
# 1                              40                           45
# 2                              54                           51
# 3                              50                           35
# 4                              88                           31
# 5                              43                           41
# 6                              43                           41
# 7                              25                           30
# 8                              58                           52
# 9                              47                           45
# 10                             63                           61
# 11                             48                           57
# 12                             68                           85
# 13                             54                           46
# 14                             62                           77
# 15                             52                           59
# 16                             50                           51
# 17                             49                           60
# 18                              0                          100
# 19                             31                           45
# 20                             48                           48
# 21                             65                           57
# 22                             29                           75
# 23                             44                           48
# 24                             36                           30
# 25                             27                           44
# 26                             37                           50
# 27                             30                           48
# 28                             50                           55
# 29                            100                           20
# ..                            ...                          ...
# 242                             0                            0
# 243                            57                           44
# 244                            42                           37
# 245                             0                            0
# 246                            65                           64
# 247                            38                           41
# 248                            62                           69
# 249                            61                           68
# 250                            56                           40
# 251                            41                           46
# 252                            54                           43
# 253                            53                           55
# 254                            62                           57
# 255                            49                           49
# 256                            50                           28
# 257                             0                           50
# 258                            60                           55
# 259                            56                           46
# 260                            43                           38
# 261                            38                           44
# 262                           100                            0
# 263                            67                           79
# 264                            21                           30
# 265                            66                           70
# 266                            21                           40
# 267                            54                           51
# 268                            64                           61
# 269                            60                           49
# 270                            58                           57
# 271                            48                           52
#
#      Air challenges won, %  Successful dribbles, %  Tackles won, %  \
# 0                       63                     100              54
# 1                       60                      67              67
# 2                       46                      27              54
# 3                        0                      38              75
# 4                       47                      33              88
# 5                       40                      43              38
# 6                       40                      43              38
# 7                       29                      38              60
# 8                       67                      38              36
# 9                       47                      52              52
# 10                      63                      67              65
# 11                      29                      56              53
# 12                      57                      86             100
# 13                      35                      61              66
# 14                      67                      75              64
# 15                      50                      71              59
# 16                      54                      64              49
# 17                      48                      54              49
# 18                       0                       0               0
# 19                      49                      45              26
# 20                      48                      51              50
# 21                      59                      71              64
# 22                      50                       0               0
# 23                      47                      71              40
# 24                      19                      63              50
# 25                      23                      50              27
# 26                      25                       0              40
# 27                      63                      57              17
# 28                      64                      67              57
# 29                       0                      33             100
# ..                     ...                     ...             ...
# 242                      0                       0               0
# 243                     62                      35              66
# 244                     46                      43              37
# 245                      0                       0               0
# 246                     54                      92              72
# 247                     29                      57              44
# 248                     56                      77              64
# 249                     53                      70              82
# 250                     35                      48              67
# 251                     47                      49              42
# 252                     52                      60              64
# 253                     48                      64              64
# 254                     67                      50              56
# 255                     24                      66              69
# 256                     33                     100              67
# 257                      0                      50               0
# 258                     63                      69              62
# 259                     59                      75              52
# 260                     21                      54              67
# 261                     20                      48              44
# 262                    100                       0               0
# 263                     57                      81              75
# 264                     31                      31              41
# 265                     70                      69              68
# 266                     40                      49              40
# 267                     63                      52              57
# 268                     64                      69              68
# 269                     61                      69              63
# 270                     36                      56              64
# 271                     67                      65              53
#
#      Accurate passes, %  xG (Expected goals)
# 0                    81                 1.74
# 1                    66                 0.00
# 2                    74                 0.60
# 3                    56                 0.12
# 4                    69                 0.39
# 5                    62                 0.79
# 6                    62                 0.79
# 7                    68                 0.72
# 8                    85                 0.00
# 9                    74                 3.95
# 10                   82                 1.37
# 11                   70                 0.84
# 12                   71                 0.08
# 13                   71                 1.31
# 14                   77                 1.12
# 15                   63                 0.10
# 16                   72                 0.13
# 17                   79                 0.05
# 18                    0                 0.00
# 19                   63                 8.11
# 20                   66                 1.57
# 21                   74                 0.10
# 22                   65                 0.00
# 23                   74                 0.56
# 24                   70                 3.77
# 25                   63                 1.18
# 26                   93                 0.29
# 27                   68                 0.23
# 28                   85                 8.86
# 29                   62                 0.00
# ..                  ...                  ...
# 242                  33                 0.00
# 243                  68                 0.09
# 244                  65                 0.53
# 245                  50                 0.00
# 246                  77                 1.17
# 247                  73                 0.83
# 248                  90                 5.31
# 249                  86                 1.15
# 250                  74                 3.78
# 251                  73                11.25
# 252                  67                 8.78
# 253                  82                 2.08
# 254                  80                 0.21
# 255                  75                 9.16
# 256                  75                 2.58
# 257                  75                 0.00
# 258                  70                 8.85
# 259                  86                 1.12
# 260                  75                 6.16
# 261                  79                 0.22
# 262                 100                 0.07
# 263                  87                 0.06
# 264                  72                 5.14
# 265                  88                 5.60
# 266                  71                 8.28
# 267                  78                 3.35
# 268                  74                 9.86
# 269                  79                 0.89
# 270                  86                 1.49
# 271                  68                 2.94
#
# [272 rows x 49 columns]

# %%
tabla.set_index('Name', inplace = True)
tabla.head()
# Out:
#                     Goals   Assists   Chances  Chances successful  \
# Name
# Nina Bruggemann  0.076923  0.000000  0.230769            0.076923
# Sofie Zdebel     0.000000  0.000000  0.000000            0.000000
# Sylwia Matysik   0.000000  0.000000  0.179462            0.000000
# Chiara Bucher    0.638298  0.000000  0.638298            0.638298
# Verena Wieder    0.253521  0.253521  0.507042            0.253521
#
#                  Сhances created     Fouls  Fouls suffered  Yellow cards  \
# Name
# Nina Bruggemann         0.153846  0.615385        0.692308      0.153846
# Sofie Zdebel            0.000000  0.947368        0.000000      0.000000
# Sylwia Matysik          0.000000  2.243270        1.345962      0.089731
# Chiara Bucher           0.000000  1.276596        0.000000      0.000000
# Verena Wieder           0.760563  0.253521        1.014085      0.000000
#
#                  Red cards  Offsides  ...  Chances, % of conversion  \
# Name                                  ...
# Nina Bruggemann        0.0  0.000000  ...                        33
# Sofie Zdebel           0.0  0.000000  ...                         0
# Sylwia Matysik         0.0  0.000000  ...                         0
# Chiara Bucher          0.0  0.638298  ...                       100
# Verena Wieder          0.0  0.760563  ...                        50
#
#                  Accurate crosses, %  Challenges won, %  \
# Name
# Nina Bruggemann                    0                 64
# Sofie Zdebel                       0                 43
# Sylwia Matysik                    50                 53
# Chiara Bucher                      0                 39
# Verena Wieder                      0                 42
#
#                  Challenges in defence won, %  Challenges in attack won, %  \
# Name
# Nina Bruggemann                            62                           69
# Sofie Zdebel                               40                           45
# Sylwia Matysik                             54                           51
# Chiara Bucher                              50                           35
# Verena Wieder                              88                           31
#
#                  Air challenges won, %  Successful dribbles, %  \
# Name
# Nina Bruggemann                     63                     100
# Sofie Zdebel                        60                      67
# Sylwia Matysik                      46                      27
# Chiara Bucher                        0                      38
# Verena Wieder                       47                      33
#
#                  Tackles won, %  Accurate passes, %  xG (Expected goals)
# Name
# Nina Bruggemann              54                  81                 1.74
# Sofie Zdebel                 67                  66                 0.00
# Sylwia Matysik               54                  74                 0.60
# Chiara Bucher                75                  56                 0.12
# Verena Wieder                88                  69                 0.39
#
# [5 rows x 48 columns]

# %%
# Filtro. Descarto a aquellas jugadoras que han disputado menos de 600 minutos

df_filtro = tabla [tabla['minutos_jugados'] > 600]
df_filtro
# Out:
#                          Goals   Assists   Chances  Chances successful  \
# Name
# Nina Bruggemann       0.076923  0.000000  0.230769            0.076923
# Sylwia Matysik        0.000000  0.000000  0.179462            0.000000
# Ann-Kathrin Vinken    0.000000  0.000000  0.000000            0.000000
# Dora Zeller           0.156522  0.104348  1.304348            0.260870
# Lilla Turanyi         0.000000  0.044510  0.133531            0.000000
# Kristin Kogel         0.000000  0.263158  0.394737            0.000000
# Lara Katinka Marti    0.000000  0.100223  0.100223            0.000000
# Henrike Sahlmann      0.000000  0.000000  0.000000            0.000000
# Milena Nikolic        0.684611  0.052662  1.158572            0.684611
# Henrietta Csiszar     0.211433  0.563821  0.422866            0.211433
# Isabel Kerschowski    0.048993  0.048993  0.048993            0.048993
# Juliane Wirtz         0.067976  0.067976  0.135952            0.067976
# Mina Tanaka           0.439024  0.109756  1.207317            0.439024
# Ivana Rudelic         0.000000  0.129496  1.035971            0.000000
# Lina Maria Magull     0.231959  0.425258  0.889175            0.309278
# S. Laudehr            0.373961  0.124654  0.747922            0.373961
# Amanda Ilestedt       0.225705  0.000000  0.451411            0.225705
# Klara Buhl            0.409556  0.409556  1.535836            0.511945
# H. Glas               0.114358  0.152478  0.419314            0.152478
# Lineth Beerensteyn    0.250278  0.150167  0.951057            0.250278
# Felicitas Rauch              0.798065  0.689238        0.943168      0.036276
# Lena Sophie Oberdorf         1.432361  1.472149        1.273210      0.437666
# J. Wedemeyer                 0.390456  0.715835        0.390456      0.000000
# S. van de Sanden             0.761636  0.507757        0.761636      0.126939
#
#                       Red cards  Offsides  ...  Chances, % of conversion  \
# Name                                       ...
# Nina Bruggemann        0.000000  0.000000  ...                        33
# Sylwia Matysik         0.000000  0.000000  ...                         0
# Ann-Kathrin Vinken     0.000000  0.000000  ...                         0
# Dora Zeller            0.000000  0.573913  ...                        20
# Lilla Turanyi          0.000000  0.044510  ...                         0
# Kristin Kogel          0.000000  0.065789  ...                         0
# Lara Katinka Marti     0.000000  0.100223  ...                         0
# Henrike Sahlmann       0.000000  0.000000  ...                         0
# Milena Nikolic         0.000000  0.263312  ...                        59
# Henrietta Csiszar      0.000000  0.000000  ...                        50
# Isabel Kerschowski     0.000000  0.048993  ...                       100
# Juliane Wirtz          0.000000  0.067976  ...                        50
# Mina Tanaka            0.000000  0.329268  ...                        36
# Ivana Rudelic          0.000000  1.294964  ...                         0
# Lina Maria Magull      0.000000  0.154639  ...                        35
# S. Laudehr             0.000000  0.249307  ...                        50
# Amanda Ilestedt        0.000000  0.056426  ...                        50
# Klara Buhl             0.000000  0.307167  ...                        33
# H. Glas                0.000000  0.000000  ...                        36
# Lineth Beerensteyn     0.000000  0.400445  ...                        26
# Sarah Zadrazil         0.000000  0.000000  ...                        67
# Carina Wenninger       0.000000  0.000000  ...                        25
# Sydney Lohmann         0.000000  0.050992  ...                        48
# Marina Hegering        0.000000  0.040036  ...                        44
# Lea Schuller           0.000000  0.997230  ...                        41
# Linda Dallmann         0.000000  0.626450  ...                        26
# Carolin Simon          0.000000  0.164735  ...                        17
# Viviane Asseyi         0.000000  0.553117  ...                        53
# Simone Boye Sorensen   0.130624  0.000000  ...                       100
# Geraldine Reuteler     0.000000  0.778659  ...                        32
# ...                         ...       ...  ...                       ...
# Gabriella Toth         0.000000  0.066128  ...                       100
# Jasmin Sehan           0.000000  0.294118  ...                        33
# Lina Hausicke          0.000000  0.000000  ...                         0
# Katharina Schiechtl    0.000000  0.000000  ...                        40
# Franziska Jaser        0.000000  0.000000  ...                         0
# Anna Hausdorff         0.000000  0.000000  ...                         0
# Agata Tarczynska       0.000000  0.821501  ...                        45
# Ricarda Walkling       0.000000  0.053731  ...                        25
# Stephanie Goddard      0.000000  0.693374  ...                         0
# Ina-Marie Timmermann   0.000000  0.000000  ...                       100
# Verena Volkmer         0.000000  0.093946  ...                         0
# Michelle Ulbrich       0.000000  0.000000  ...                        50
# Jana Radosavljevic     0.000000  0.000000  ...                        33
# Lena Goessling         0.000000  0.045918  ...                        67
# K. Hendrich            0.000000  0.000000  ...                        50
# Pia-Sophie Wolter      0.000000  0.416667  ...                        54
# Zsanett Jakabfi        0.000000  1.096076  ...                        33
# Fridolina Rolfo        0.000000  0.599112  ...                        14
# Ingrid Syrstad Engen   0.000000  0.000000  ...                        44
# Svenja Anette Huth     0.000000  0.281030  ...                        14
# Alexandra Popp         0.000000  0.196650  ...                        42
# Karina Saevik          0.000000  1.242038  ...                        18
# Sara Doorsoun-Khajeh   0.000000  0.000000  ...                       100
# R. Blomqvist           0.000000  0.510204  ...                        33
# D. Janssen             0.000000  0.000000  ...                        24
# Ewa Pajor              0.000000  0.801527  ...                        44
# Felicitas Rauch        0.000000  0.145103  ...                        31
# Lena Sophie Oberdorf   0.000000  0.039788  ...                        35
# J. Wedemeyer           0.000000  0.000000  ...                        20
# S. van de Sanden       0.000000  0.761636  ...                        50
#
#                       Accurate crosses, %  Challenges won, %  \
# Name
# Nina Bruggemann                         0                 64
# Sylwia Matysik                         50                 53
# Ann-Kathrin Vinken                    100                 57
# Dora Zeller                            23                 46
# Lilla Turanyi                           0                 62
# Kristin Kogel                          27                 50
# Lara Katinka Marti                     15                 50
# Henrike Sahlmann                       57                 52
# Milena Nikolic                         50                 42
# Henrietta Csiszar                      39                 48
# Isabel Kerschowski                     47                 62
# Juliane Wirtz                          33                 46
# Mina Tanaka                             0                 31
# Ivana Rudelic                          17                 39
# Lina Maria Magull                      50                 53
# S. Laudehr                             20                 51
# Amanda Ilestedt                        26                 67
# Klara Buhl                             15                 37
# H. Glas                                18                 59
# Lineth Beerensteyn                     15                 40
# Sarah Zadrazil                         35                 61
# Carina Wenninger                       50                 66
# Sydney Lohmann                         27                 47
# Marina Hegering                        63                 73
# Lea Schuller                           24                 34
# Linda Dallmann                         38                 44
# Carolin Simon                          32                 62
# Viviane Asseyi                         21                 40
# Simone Boye Sorensen                    0                 59
# Geraldine Reuteler                     28                 45
# ...                                   ...                ...
# Gabriella Toth                         43                 58
# Jasmin Sehan                           20                 45
# Lina Hausicke                           0                 63
# Katharina Schiechtl                    17                 56
# Franziska Jaser                         0                 69
# Anna Hausdorff                          0                 63
# Agata Tarczynska                       36                 31
# Ricarda Walkling                       50                 47
# Stephanie Goddard                      50                 43
# Ina-Marie Timmermann                   22                 53
# Verena Volkmer                         27                 39
# Michelle Ulbrich                      100                 65
# Jana Radosavljevic                     33                 40
# Lena Goessling                         47                 64
# K. Hendrich                            30                 63
# Pia-Sophie Wolter                      15                 46
# Zsanett Jakabfi                        40                 45
# Fridolina Rolfo                        22                 47
# Ingrid Syrstad Engen                   33                 54
# Svenja Anette Huth                     29                 49
# Alexandra Popp                         36                 57
# Karina Saevik                          25                 39
# Sara Doorsoun-Khajeh                   50                 69
# R. Blomqvist                           36                 27
# D. Janssen                             25                 67
# Ewa Pajor                              37                 37
# Felicitas Rauch                        34                 53
# Lena Sophie Oberdorf                   20                 62
# J. Wedemeyer                           31                 56
# S. van de Sanden                       29                 51
#
#                       Challenges in defence won, %  \
# Name
# Nina Bruggemann                                 62
# Sylwia Matysik                                  54
# Ann-Kathrin Vinken                              58
# Dora Zeller                                     47
# Lilla Turanyi                                   63
# Kristin Kogel                                   54
# Lara Katinka Marti                              50
# Henrike Sahlmann                                49
# Milena Nikolic                                  31
# Henrietta Csiszar                               48
# Isabel Kerschowski                              65
# Juliane Wirtz                                   44
# Mina Tanaka                                     36
# Ivana Rudelic                                   27
# Lina Maria Magull                               50
# S. Laudehr                                      60
# Amanda Ilestedt                                 72
# Klara Buhl                                      32
# H. Glas                                         68
# Lineth Beerensteyn                              37
# Sarah Zadrazil                                  60
# Carina Wenninger                                71
# Sydney Lohmann                                  49
# Marina Hegering                                 73
# Lea Schuller                                    25
# Linda Dallmann                                  48
# Carolin Simon                                   60
# Viviane Asseyi                                  51
# Simone Boye Sorensen                            60
# Geraldine Reuteler                              46
# ...                                            ...
# Gabriella Toth                                  58
# Jasmin Sehan                                    51
# Lina Hausicke                                   64
# Katharina Schiechtl                             58
# Franziska Jaser                                 65
# Anna Hausdorff                                  69
# Agata Tarczynska                                21
# Ricarda Walkling                                49
# Stephanie Goddard                               50
# Ina-Marie Timmermann                            57
# Verena Volkmer                                  42
# Michelle Ulbrich                                65
# Jana Radosavljevic                              38
# Lena Goessling                                  62
# K. Hendrich                                     61
# Pia-Sophie Wolter                               56
# Zsanett Jakabfi                                 41
# Fridolina Rolfo                                 54
# Ingrid Syrstad Engen                            53
# Svenja Anette Huth                              49
# Alexandra Popp                                  60
# Karina Saevik                                   43
# Sara Doorsoun-Khajeh                            67
# R. Blomqvist                                    21
# D. Janssen                                      66
# Ewa Pajor                                       21
# Felicitas Rauch                                 54
# Lena Sophie Oberdorf                            64
# J. Wedemeyer                                    60
# S. van de Sanden                                48
#
#                       Challenges in attack won, %  Air challenges won, %  \
# Name
# Nina Bruggemann                                69                     63
# Sylwia Matysik                                 51                     46
# Ann-Kathrin Vinken                             52                     67
# Dora Zeller                                    45                     47
# Lilla Turanyi                                  61                     63
# Kristin Kogel                                  46                     35
# Lara Katinka Marti                             51                     54
# Henrike Sahlmann                               60                     48
# Milena Nikolic                                 45                     49
# Henrietta Csiszar                              48                     48
# Isabel Kerschowski                             57                     59
# Juliane Wirtz                                  48                     47
# Mina Tanaka                                    30                     19
# Ivana Rudelic                                  44                     23
# Lina Maria Magull                              55                     64
# S. Laudehr                                     44                     47
# Amanda Ilestedt                                54                     80
# Klara Buhl                                     38                     27
# H. Glas                                        49                     74
# Lineth Beerensteyn                             42                     31
# Sarah Zadrazil                                 63                     60
# Carina Wenninger                               52                     62
# Sydney Lohmann                                 46                     55
# Marina Hegering                                71                     77
# Lea Schuller                                   35                     36
# Linda Dallmann                                 43                     41
# Carolin Simon                                  64                     55
# Viviane Asseyi                                 36                     44
# Simone Boye Sorensen                           54                     67
# Geraldine Reuteler                             45                     32
# ...                                           ...                    ...
# Gabriella Toth                                 60                     31
# Jasmin Sehan                                   41                     42
# Lina Hausicke                                  63                     67
# Katharina Schiechtl                            52                     47
# Franziska Jaser                                86                     67
# Anna Hausdorff                                 33                     72
# Agata Tarczynska                               33                     21
# Ricarda Walkling                               46                     30
# Stephanie Goddard                              39                     43
# Ina-Marie Timmermann                           44                     62
# Verena Volkmer                                 37                     46
# Michelle Ulbrich                               64                     54
# Jana Radosavljevic                             41                     29
# Lena Goessling                                 69                     56
# K. Hendrich                                    68                     53
# Pia-Sophie Wolter                              40                     35
# Zsanett Jakabfi                                46                     47
# Fridolina Rolfo                                43                     52
# Ingrid Syrstad Engen                           55                     48
# Svenja Anette Huth                             49                     24
# Alexandra Popp                                 55                     63
# Karina Saevik                                  38                     21
# Sara Doorsoun-Khajeh                           79                     57
# R. Blomqvist                                   30                     31
# D. Janssen                                     70                     70
# Ewa Pajor                                      40                     40
# Felicitas Rauch                                51                     63
# Lena Sophie Oberdorf                           61                     64
# J. Wedemeyer                                   49                     61
# S. van de Sanden                               52                     67
#
#                       Successful dribbles, %  Tackles won, %  \
# Name
# Nina Bruggemann                          100              54
# Sylwia Matysik                            27              54
# Ann-Kathrin Vinken                        38              36
# Dora Zeller                               52              52
# Lilla Turanyi                             67              65
# Kristin Kogel                             61              66
# Lara Katinka Marti                        64              49
# Henrike Sahlmann                          54              49
# Milena Nikolic                            45              26
# Henrietta Csiszar                         51              50
# Isabel Kerschowski                        71              64
# Juliane Wirtz                             71              40
# Mina Tanaka                               63              50
# Ivana Rudelic                             50              27
# Lina Maria Magull                         67              57
# S. Laudehr                                43              61
# Amanda Ilestedt                           27              67
# Klara Buhl                                45              39
# H. Glas                                   49              80
# Lineth Beerensteyn                        57              40
# Sarah Zadrazil                            76              67
# Carina Wenninger                          67              76
# Sydney Lohmann                            54              60
# Marina Hegering                           73              70
# Lea Schuller                              49              26
# Linda Dallmann                            57              58
# Carolin Simon                             75              62
# Viviane Asseyi                            38              54
# Simone Boye Sorensen                      71              57
# Geraldine Reuteler                        65              57
# ...                                      ...             ...
# Gabriella Toth                            65              58
# Jasmin Sehan                              50              61
# Lina Hausicke                             57              70
# Katharina Schiechtl                       65              58
# Franziska Jaser                          100              67
# Anna Hausdorff                            60              71
# Agata Tarczynska                          45              27
# Ricarda Walkling                          53              59
# Stephanie Goddard                         47              62
# Ina-Marie Timmermann                      35              66
# Verena Volkmer                            43              37
# Michelle Ulbrich                          92              72
# Jana Radosavljevic                        57              44
# Lena Goessling                            77              64
# K. Hendrich                               70              82
# Pia-Sophie Wolter                         48              67
# Zsanett Jakabfi                           49              42
# Fridolina Rolfo                           60              64
# Ingrid Syrstad Engen                      64              64
# Svenja Anette Huth                        66              69
# Alexandra Popp                            69              62
# Karina Saevik                             54              67
# Sara Doorsoun-Khajeh                      81              75
# R. Blomqvist                              31              41
# D. Janssen                                69              68
# Ewa Pajor                                 49              40
# Felicitas Rauch                           52              57
# Lena Sophie Oberdorf                      69              68
# J. Wedemeyer                              69              63
# S. van de Sanden                          65              53
#
#                       Accurate passes, %  xG (Expected goals)
# Name
# Nina Bruggemann                       81                 1.74
# Sylwia Matysik                        74                 0.60
# Ann-Kathrin Vinken                    85                 0.00
# Dora Zeller                           74                 3.95
# Lilla Turanyi                         82                 1.37
# Kristin Kogel                         71                 1.31
# Lara Katinka Marti                    72                 0.13
# Henrike Sahlmann                      79                 0.05
# Milena Nikolic                        63                 8.11
# Henrietta Csiszar                     66                 1.57
# Isabel Kerschowski                    74                 0.10
# Juliane Wirtz                         74                 0.56
# Mina Tanaka                           70                 3.77
# Ivana Rudelic                         63                 1.18
# Lina Maria Magull                     85                 8.86
# S. Laudehr                            89                 1.57
# Amanda Ilestedt                       81                 2.51
# Klara Buhl                            68                 7.46
# H. Glas                               83                 2.02
# Lineth Beerensteyn                    70                 5.84
# Sarah Zadrazil                        82                 1.14
# Carina Wenninger                      86                 1.67
# Sydney Lohmann                        76                10.81
# Marina Hegering                       89                 6.22
# Lea Schuller                          67                 9.63
# Linda Dallmann                        83                 6.13
# Carolin Simon                         80                 1.10
# Viviane Asseyi                        70                 5.65
# Simone Boye Sorensen                  92                 0.76
# Geraldine Reuteler                    77                 3.43
# ...                                  ...                  ...
# Gabriella Toth                        75                 0.31
# Jasmin Sehan                          65                 0.51
# Lina Hausicke                         79                 0.00
# Katharina Schiechtl                   71                 2.16
# Franziska Jaser                       86                 0.04
# Anna Hausdorff                        76                 0.02
# Agata Tarczynska                      74                 3.25
# Ricarda Walkling                      75                 2.84
# Stephanie Goddard                     72                 0.59
# Ina-Marie Timmermann                  68                 0.09
# Verena Volkmer                        65                 0.53
# Michelle Ulbrich                      77                 1.17
# Jana Radosavljevic                    73                 0.83
# Lena Goessling                        90                 5.31
# K. Hendrich                           86                 1.15
# Pia-Sophie Wolter                     74                 3.78
# Zsanett Jakabfi                       73                11.25
# Fridolina Rolfo                       67                 8.78
# Ingrid Syrstad Engen                  82                 2.08
# Svenja Anette Huth                    75                 9.16
# Alexandra Popp                        70                 8.85
# Karina Saevik                         75                 6.16
# Sara Doorsoun-Khajeh                  87                 0.06
# R. Blomqvist                          72                 5.14
# D. Janssen                            88                 5.60
# Ewa Pajor                             71                 8.28
# Felicitas Rauch                       78                 3.35
# Lena Sophie Oberdorf                  74                 9.86
# J. Wedemeyer                          79                 0.89
# S. van de Sanden                      68                 2.94
#
# [176 rows x 48 columns]

# %% [markdown]
# # Radar charts

# %%
# Elimino las columnas de datos que no son relevantes para realizar los radar charts

tabla_radar = tabla.drop (['Team','Position','Matches played','Nationality','National_team','Foot','Age','Height',
                          'Weight','Matches 90 min'], axis=1)
tabla_radar.head()
# Out:
#                     Goals   Assists   Chances  Chances successful  \
# Name
# Nina Bruggemann  0.076923  0.000000  0.230769            0.076923
# Sofie Zdebel     0.000000  0.000000  0.000000            0.000000
# Sylwia Matysik   0.000000  0.000000  0.179462            0.000000
# Chiara Bucher    0.638298  0.000000  0.638298            0.638298
# Verena Wieder    0.253521  0.253521  0.507042            0.253521
#
#                  Сhances created     Fouls  Fouls suffered  Yellow cards  \
# Name
# Nina Bruggemann         0.153846  0.615385        0.692308      0.153846
# Sofie Zdebel            0.000000  0.947368        0.000000      0.000000
# Sylwia Matysik          0.000000  2.243270        1.345962      0.089731
# Chiara Bucher           0.000000  1.276596        0.000000      0.000000
# Verena Wieder           0.760563  0.253521        1.014085      0.000000
#
#                  Red cards  Offsides  ...  Chances, % of conversion  \
# Name                                  ...
# Nina Bruggemann        0.0  0.000000  ...                        33
# Sofie Zdebel           0.0  0.000000  ...                         0
# Sylwia Matysik         0.0  0.000000  ...                         0
# Chiara Bucher          0.0  0.638298  ...                       100
# Verena Wieder          0.0  0.760563  ...                        50
#
#                  Accurate crosses, %  Challenges won, %  \
# Name
# Nina Bruggemann                    0                 64
# Sofie Zdebel                       0                 43
# Sylwia Matysik                    50                 53
# Chiara Bucher                      0                 39
# Verena Wieder                      0                 42
#
#                  Challenges in defence won, %  Challenges in attack won, %  \
# Name
# Nina Bruggemann                            62                           69
# Sofie Zdebel                               40                           45
# Sylwia Matysik                             54                           51
# Chiara Bucher                              50                           35
# Verena Wieder                              88                           31
#
#                  Air challenges won, %  Successful dribbles, %  \
# Name
# Nina Bruggemann                     63                     100
# Sofie Zdebel                        60                      67
# Sylwia Matysik                      46                      27
# Chiara Bucher                        0                      38
# Verena Wieder                       47                      33
#
#                  Tackles won, %  Accurate passes, %  xG (Expected goals)
# Name
# Nina Bruggemann              54                  81                 1.74
# Sofie Zdebel                 67                  66                 0.00
# Sylwia Matysik               54                  74                 0.60
# Chiara Bucher                75                  56                 0.12
# Verena Wieder                88                  69                 0.39
#
# [5 rows x 38 columns]

# %%
from sklearn import preprocessing

x = tabla_radar.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
df_normalizado_radar = pd.DataFrame(x_scaled)
df_normalizado_radar.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.052991  0.000000  0.063590  0.052991  0.035897  0.034188  0.057692
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.052632  0.000000
# 2  0.000000  0.000000  0.049452  0.000000  0.000000  0.124626  0.112164
# 3  0.439716  0.000000  0.175887  0.439716  0.000000  0.070922  0.000000
# 4  0.174648  0.273239  0.139718  0.174648  0.177465  0.014085  0.084507
#
#          7    8         9   ...    28   29    30    31    32    33    34  \
# 0  0.162393  0.0  0.000000  ...  0.33  0.0  0.64  0.62  0.69  0.63  1.00
# 1  0.000000  0.0  0.000000  ...  0.00  0.0  0.43  0.40  0.45  0.60  0.67
# 2  0.094716  0.0  0.000000  ...  0.00  0.5  0.53  0.54  0.51  0.46  0.27
# 3  0.000000  0.0  0.244681  ...  1.00  0.0  0.39  0.50  0.35  0.00  0.38
# 4  0.000000  0.0  0.291549  ...  0.50  0.0  0.42  0.88  0.31  0.47  0.33
#
#      35    36        37
# 0  0.54  0.81  0.099202
# 1  0.67  0.66  0.000000
# 2  0.54  0.74  0.034208
# 3  0.75  0.56  0.006842
# 4  0.88  0.69  0.022235
#
# [5 rows x 38 columns]

# %%
# Vuelvo a normalizar los datos pero esta vez con 'tabla' que mantiene los nombres como indice

df_normalizado_radar = (tabla_radar - tabla_radar.min()) / (tabla_radar.max() - tabla_radar.min())
df_normalizado_radar.head()
# Out:
#                     Goals   Assists   Chances  Chances successful  \
# Name
# Nina Bruggemann  0.052991  0.000000  0.063590            0.052991
# Sofie Zdebel     0.000000  0.000000  0.000000            0.000000
# Sylwia Matysik   0.000000  0.000000  0.049452            0.000000
# Chiara Bucher    0.439716  0.000000  0.175887            0.439716
# Verena Wieder    0.174648  0.273239  0.139718            0.174648
#
#                  Сhances created     Fouls  Fouls suffered  Yellow cards  \
# Name
# Nina Bruggemann         0.035897  0.034188        0.057692      0.162393
# Sofie Zdebel            0.000000  0.052632        0.000000      0.000000
# Sylwia Matysik          0.000000  0.124626        0.112164      0.094716
# Chiara Bucher           0.000000  0.070922        0.000000      0.000000
# Verena Wieder           0.177465  0.014085        0.084507      0.000000
#
#                  Red cards  Offsides  ...  Chances, % of conversion  \
# Name                                  ...
# Nina Bruggemann        0.0  0.000000  ...                      0.33
# Sofie Zdebel           0.0  0.000000  ...                      0.00
# Sylwia Matysik         0.0  0.000000  ...                      0.00
# Chiara Bucher          0.0  0.244681  ...                      1.00
# Verena Wieder          0.0  0.291549  ...                      0.50
#
#                  Accurate crosses, %  Challenges won, %  \
# Name
# Nina Bruggemann                  0.0               0.64
# Sofie Zdebel                     0.0               0.43
# Sylwia Matysik                   0.5               0.53
# Chiara Bucher                    0.0               0.39
# Verena Wieder                    0.0               0.42
#
#                  Challenges in defence won, %  Challenges in attack won, %  \
# Name
# Nina Bruggemann                          0.62                         0.69
# Sofie Zdebel                             0.40                         0.45
# Sylwia Matysik                           0.54                         0.51
# Chiara Bucher                            0.50                         0.35
# Verena Wieder                            0.88                         0.31
#
#                  Air challenges won, %  Successful dribbles, %  \
# Name
# Nina Bruggemann                   0.63                    1.00
# Sofie Zdebel                      0.60                    0.67
# Sylwia Matysik                    0.46                    0.27
# Chiara Bucher                     0.00                    0.38
# Verena Wieder                     0.47                    0.33
#
#                  Tackles won, %  Accurate passes, %  xG (Expected goals)
# Name
# Nina Bruggemann            0.54                0.81             0.099202
# Sofie Zdebel               0.67                0.66             0.000000
# Sylwia Matysik             0.54                0.74             0.034208
# Chiara Bucher              0.75                0.56             0.006842
# Verena Wieder              0.88                0.69             0.022235
#
# [5 rows x 38 columns]

# %%
# Es necesario decidir que caracteristicas del juego son necesarias para las distintas demarcaciones
# Para ello vamos a una lista con los tipos de caract. del juego

index_columns = tabla_radar.columns                      # Obtengo una lista con las etiquetas de las columnas
lista_nombres_columnas = list(index_columns)          # Almaceno en una variable dicha lista con los nombres de las columnas.
lista_nombres_columnas
# Out:
# ['Goals',
#  'Assists',
#  'Chances',
#  'Chances successful',
#  'Сhances created',
#  'Fouls',
#  'Fouls suffered',
#  'Yellow cards',
#  'Red cards',
#  'Offsides',
#  'Shots',
#  'Shots on target',
#  'Passes',
#  'Key passes',
#  'Crosses',
#  'Lost balls',
#  'Lost balls in own half',
#  'Ball recoveries',
#  "Ball recoveries in opponent's half",
#  'Challenges',
#  'Defensive challenges',
#  'Attacking challenges',
#  'Air challenges',
#  'Dribbles',
#  'Tackles',
#  'Ball interceptions',
#  'Free ball pick ups',
#  'minutos_jugados',
#  'Chances, % of conversion',
#  'Accurate crosses, %',
#  'Challenges won, %',
#  'Challenges in defence won, %',
#  'Challenges in attack won, %',
#  'Air challenges won, %',
#  'Successful dribbles, %',
#  'Tackles won, %',
#  'Accurate passes, %',
#  'xG (Expected goals)']

# %%
len(lista_nombres_columnas)
# Out:
# 38

# %% [markdown]
# # Defensas

# %%
def radar_chart_DEFENSA (name_player):
    

    features = ['Air challenges','Ball interceptions', 'Ball recoveries','Challenges','Crosses',
                'Defensive challenges','Dribbles', 'Successful dribbles, %']
    
    features_data = [df_normalizado_radar.loc [name_player,'Air challenges'],
                     df_normalizado_radar.loc [name_player,'Ball interceptions'],
                     df_normalizado_radar.loc [name_player,"Ball recoveries"], 
                     df_normalizado_radar.loc [name_player,'Challenges'],
                     df_normalizado_radar.loc [name_player,'Crosses'],
                     df_normalizado_radar.loc [name_player,"Defensive challenges"], 
                     df_normalizado_radar.loc [name_player,'Dribbles'],
                     df_normalizado_radar.loc [name_player,'Successful dribbles, %']]
    
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
def radar_chart_DEFENSA2 (name_player):
    

    features = ['Fouls','Free ball pick ups','Lost balls','Lost balls in own half','Passes','Yellow cards','Red cards',
                'Tackles']
    
    features_data = [df_normalizado_radar.loc [name_player,'Fouls'],
                     df_normalizado_radar.loc [name_player,'Free ball pick ups'],
                     df_normalizado_radar.loc [name_player,"Lost balls"], 
                     df_normalizado_radar.loc [name_player,'Lost balls in own half'],
                     df_normalizado_radar.loc [name_player,'Passes'],
                     df_normalizado_radar.loc [name_player,"Yellow cards"], 
                     df_normalizado_radar.loc [name_player,'Red cards'],
                     df_normalizado_radar.loc [name_player,'Tackles']]
    
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
def radar_chart_DEFENSA3 (name_player):
    

    features = ["Ball recoveries in opponent's half",'Accurate crosses, %','Challenges won, %',
                'Challenges in defence won, %','Air challenges won, %','Successful dribbles, %','Tackles won, %',
                'Accurate passes, %']
    
    features_data = [df_normalizado_radar.loc [name_player,"Ball recoveries in opponent's half"],
                     df_normalizado_radar.loc [name_player,'Accurate crosses, %'],
                     df_normalizado_radar.loc [name_player,"Challenges won, %"], 
                     df_normalizado_radar.loc [name_player,'Challenges in defence won, %'],
                     df_normalizado_radar.loc [name_player,'Air challenges won, %'],
                     df_normalizado_radar.loc [name_player,"Successful dribbles, %"], 
                     df_normalizado_radar.loc [name_player,'Tackles won, %'],
                     df_normalizado_radar.loc [name_player,'Accurate passes, %']]
    
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
radar_chart_DEFENSA ('H. Glas')

# %%
radar_chart_DEFENSA2 ('H. Glas')

# %%
radar_chart_DEFENSA3 ('H. Glas')

# %% [markdown]
# # Medio centro defensivo

# %%
def radar_chart_MED_DEF (name_player):
    

    features = ['Ball interceptions',"Ball recoveries",'Challenges','Crosses',"Defensive challenges",'Fouls',
                'Lost balls','Lost balls in own half']
    features_data = [df_normalizado_radar.loc [name_player,'Ball interceptions'],
                     df_normalizado_radar.loc [name_player,"Ball recoveries"],
                     df_normalizado_radar.loc [name_player,'Challenges'],
                     df_normalizado_radar.loc [name_player,"Crosses"], 
                     df_normalizado_radar.loc [name_player,"Defensive challenges"],
                     df_normalizado_radar.loc [name_player,'Fouls'], 
                     df_normalizado_radar.loc [name_player,'Lost balls'],
                     df_normalizado_radar.loc [name_player,'Lost balls in own half']]
                     
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
def radar_chart_MED_DEF2 (name_player):
    

    features = ['Passes','Tackles','Red cards', 'Yellow cards', "Ball recoveries in opponent's half",'Fouls suffered',
                'Assists','Dribbles']
    
    features_data = [df_normalizado_radar.loc [name_player,'Passes'],
                     df_normalizado_radar.loc [name_player,"Tackles"],
                     df_normalizado_radar.loc [name_player,'Red cards'],
                     df_normalizado_radar.loc [name_player,"Yellow cards"], 
                     df_normalizado_radar.loc [name_player,"Ball recoveries in opponent's half"],
                     df_normalizado_radar.loc [name_player,'Fouls suffered'], 
                     df_normalizado_radar.loc [name_player,'Assists'],
                     df_normalizado_radar.loc [name_player,'Dribbles']]
                     
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
def radar_chart_MED_DEF3 (name_player):
    

    features = ['Challenges in defence won, %','Accurate crosses, %','Challenges in attack won, %','Successful dribbles, %',
                'Air challenges','Air challenges won, %','Free ball pick ups','Challenges won, %']
    
    features_data = [df_normalizado_radar.loc [name_player,'Challenges in defence won, %'],
                     df_normalizado_radar.loc [name_player,"Accurate crosses, %"],
                     df_normalizado_radar.loc [name_player,'Challenges in attack won, %'],
                     df_normalizado_radar.loc [name_player,"Successful dribbles, %"], 
                     df_normalizado_radar.loc [name_player,"Air challenges"],
                     df_normalizado_radar.loc [name_player,'Air challenges won, %'], 
                     df_normalizado_radar.loc [name_player,'Free ball pick ups'],
                     df_normalizado_radar.loc [name_player,'Challenges won, %']]
                     
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
radar_chart_MED_DEF ('Lina Maria Magull')

# %%
radar_chart_MED_DEF2 ('Lina Maria Magull')

# %%
radar_chart_MED_DEF3 ('Lina Maria Magull')

# %% [markdown]
# # Centrocampista ofensivo

# %%
def radar_chart_MED_OF (name_player):
    

    features = ['Challenges','Lost balls','Fouls','Key passes','Ball interceptions',"Ball recoveries in opponent's half",
                'Attacking challenges','Assists']
    
    features_data = [df_normalizado_radar.loc [name_player,'Challenges'],
                     df_normalizado_radar.loc [name_player,"Lost balls"],
                     df_normalizado_radar.loc [name_player,'Fouls'],
                     df_normalizado_radar.loc [name_player,"Key passes"], 
                     df_normalizado_radar.loc [name_player,"Ball interceptions"],
                     df_normalizado_radar.loc [name_player,"Ball recoveries in opponent's half"], 
                     df_normalizado_radar.loc [name_player,'Attacking challenges'],
                     df_normalizado_radar.loc [name_player,'Assists']]
                     
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
def radar_chart_MED_OF2 (name_player):
    

    features = ['Fouls suffered','Dribbles','Chances successful', 'Chances','Successful dribbles, %',
                'Challenges in attack won, %','Chances, % of conversion','Сhances created']
    
    features_data = [df_normalizado_radar.loc [name_player,'Fouls suffered'],
                     df_normalizado_radar.loc [name_player,"Dribbles"],
                     df_normalizado_radar.loc [name_player,'Chances successful'],
                     df_normalizado_radar.loc [name_player,"Chances"], 
                     df_normalizado_radar.loc [name_player,"Successful dribbles, %"],
                     df_normalizado_radar.loc [name_player,"Challenges in attack won, %"], 
                     df_normalizado_radar.loc [name_player,'Chances, % of conversion'],
                     df_normalizado_radar.loc [name_player,'Сhances created']]
                     
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
def radar_chart_MED_OF3 (name_player):
    

    features = ['Shots on target','Shots','Passes','Challenges won, %','Air challenges won, %','Assists',
                'Offsides','Free ball pick ups']
    
    features_data = [df_normalizado_radar.loc [name_player,'Shots on target'],
                     df_normalizado_radar.loc [name_player,"Shots"],
                     df_normalizado_radar.loc [name_player,'Passes'],
                     df_normalizado_radar.loc [name_player,"Challenges won, %"], 
                     df_normalizado_radar.loc [name_player,"Air challenges won, %"],
                     df_normalizado_radar.loc [name_player,"Assists"], 
                     df_normalizado_radar.loc [name_player,'Offsides'],
                     df_normalizado_radar.loc [name_player,'Free ball pick ups']]
                     
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
radar_chart_MED_OF ('Viviane Asseyi')

# %%
radar_chart_MED_OF2 ('Viviane Asseyi')

# %%
radar_chart_MED_OF3 ('Viviane Asseyi')

# %% [markdown]
# # Delanteras

# %%
def radar_chart_DELANTERA (name_player):
    

    features = ['Air challenges','Assists','Attacking challenges','Challenges','Chances','Chances successful','Dribbles',
                'Fouls suffered']
    
    features_data = [df_normalizado_radar.loc [name_player,'Air challenges'],
                     df_normalizado_radar.loc [name_player,"Assists"],
                     df_normalizado_radar.loc [name_player,'Attacking challenges'],
                     df_normalizado_radar.loc [name_player,"Challenges"], 
                     df_normalizado_radar.loc [name_player,"Chances"],
                     df_normalizado_radar.loc [name_player,"Chances successful"], 
                     df_normalizado_radar.loc [name_player,'Dribbles'],
                     df_normalizado_radar.loc [name_player,'Fouls suffered']]
                     
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
def radar_chart_DELANTERA2 (name_player):
    

    features = ['Free ball pick ups','Goals','Key passes','Lost balls','Offsides','Passes','Shots','Shots on target']
    
    features_data = [df_normalizado_radar.loc [name_player,'Free ball pick ups'],
                     df_normalizado_radar.loc [name_player,"Goals"],
                     df_normalizado_radar.loc [name_player,'Key passes'],
                     df_normalizado_radar.loc [name_player,"Lost balls"], 
                     df_normalizado_radar.loc [name_player,"Offsides"],
                     df_normalizado_radar.loc [name_player,"Passes"], 
                     df_normalizado_radar.loc [name_player,'Shots'],
                     df_normalizado_radar.loc [name_player,'Shots on target']]
                     
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
def radar_chart_DELANTERA3 (name_player):
    

    features = ['Assists','Сhances created','Chances, % of conversion','Challenges won, %',
                'Challenges in attack won, %','Air challenges won, %','Successful dribbles, %','Accurate passes, %']
    
    features_data = [df_normalizado_radar.loc [name_player,'Assists'],
                     df_normalizado_radar.loc [name_player,"Сhances created"],
                     df_normalizado_radar.loc [name_player,'Chances, % of conversion'],
                     df_normalizado_radar.loc [name_player,"Challenges won, %"], 
                     df_normalizado_radar.loc [name_player,"Challenges in attack won, %"],
                     df_normalizado_radar.loc [name_player,"Air challenges won, %"], 
                     df_normalizado_radar.loc [name_player,'Successful dribbles, %'],
                     df_normalizado_radar.loc [name_player,'Accurate passes, %']]
                     
    features_data =  np.concatenate ((features_data,[features_data[0]]))
    
    label_placement = np.linspace(start = 0, stop =2*np.pi, num=len (features_data))
    plt.figure (figsize = (6,6))
    plt.subplot(polar=True)
    plt.plot(label_placement,features_data)
    lines,labels = plt.thetagrids(np.degrees(label_placement),labels = features)

# %%
radar_chart_DELANTERA ('Lea Schuller')

# %%
radar_chart_DELANTERA2 ('Lea Schuller')

# %%
radar_chart_DELANTERA3 ('Lea Schuller')
